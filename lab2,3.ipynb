# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaguevil/MMVSULAB1/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная работа ***№2***
#
#
#
#
# *Выполнил студент группы КМА Некрасов Артем*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
url='https://raw.githubusercontent.com/Vaguevil/MMVSULAB1/main/EKB.csv'
df=pd.read_csv(url)
print(df)
years=np.array(df['Years'])
population=np.array(df['Population '])
print(years)
plt.plot(df['Years'],df['Population '])

plt.xlabel('Years')
plt.ylabel('Population ')
plt.title('Population of Ekaterinburg')
plt.show()
# Out:
#     Years  Population
# 0    1986      1310000
# 1    1987      1331000
# 2    1988      1351000
# 3    1989      1364621
# 4    1990      1304000
# 5    1991      1375000
# 6    1992      1371000
# 7    1993      1358000
# 8    1994      1347000
# 9    1995      1278000
# 10   1996      1276000
# 11   1997      1275000
# 12   1998      1272000
# 13   1999      1272900
# 14   2000      1266300
# 15   2001      1256900
# 16   2002      1293537
# 17   2003      1293500
# 18   2004      1334400
# 19   2005      1304300
# 20   2006      1308400
# 21   2007      1315100
# 22   2008      1323000
# 23   2009      1332264
# 24   2010      1349772
# 25   2011      1350100
# 26   2012      1377738
# 27   2013      1396074
# 28   2014      1412346
# 29   2015      1428042
# 30   2016      1444439
# 31   2017      1455904
# 32   2018      1468833
# 33   2019      1483119
# 34   2020      1493749
# [1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999
#  2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020]

# %% [markdown]
# #График населения Екатеринбурга

# %%
import matplotlib.pyplot as plt 
import pandas as pd
from scipy.integrate import odeint 


data = {'year': [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003],
        'pop': [1375000, 1371000, 1358000, 1347000, 1278000, 1276000, 1275000, 1272000, 1272900, 1266300, 1256900, 1293537, 1293500]}
df = pd.DataFrame(data)

plt.plot(df['year'], df['pop'])

plt.xlabel('year')
plt.ylabel('pop')
plt.title('Population Ekaterinburg')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dydt(x,t):
  k=-0.002569
  return k*x
t=np.linspace(0,13,13)

solve = odeint(dydt, 3067589, t=t)
solve = solve.flatten()
d = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
k = [1375000, 1371000, 1358000, 1347000, 1278000, 1276000, 1275000, 1272000, 1272900, 1266300, 1256900, 1293537, 1293500]

# %matplotlib inline

plt.plot(d,solve,label=r"x'=kx")
plt.plot(d, k)
plt.grid(True)
plt.legend()
plt.show()
